# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from collections import Counter

# %%
data=pd.read_csv(os.getcwd()+'/books_meloman.csv').to_numpy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6872/3404904961.py in <module>
# ----> 1 data=pd.read_csv(os.getcwd()+'/books_meloman.csv').to_numpy().astype(int)
#
# ValueError: invalid literal for int() with base 10: 'Бекжігітова К. : Ойыңды өзгертіп, өміріңді өзгерт'

# %%
genres = Counter(data[:,4].tolist())
publishers = Counter(data[:,5].tolist())
years = data[:,7].tolist()
languages = Counter(data[:,8].tolist())
ages = Counter(data[:,6].tolist())

# %%
def plotStrings(array):
    return pd.DataFrame.from_dict(array, orient='index').plot(y=0,figsize=(15,10),kind="bar")

# %%
plotStrings(ages)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6872/3101068427.py in <module>
# ----> 1 plotStrings(years)
#
# /tmp/ipykernel_6872/1671778287.py in plotStrings(array)
#       1 def plotStrings(array):
# ----> 2     return pd.DataFrame.from_dict(array, orient='index').plot(y=0,figsize=(15,10),kind="bar")
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1581             if len(data) > 0:
#    1582                 # TODO speed up Series case
# -> 1583                 if isinstance(list(data.values())[0], (Series, dict)):
#    1584                     data = _from_nested_dict(data)
#    1585                 else:
#
# AttributeError: 'list' object has no attribute 'values'

# %%
plt.figure(figsize=(15,10))
plt.hist(years)
# Out:
# (array([  5.,   4.,   5., 173., 103., 509., 145.,  32.,  16.,   7.]),
#  array([ 0. ,  2.7,  5.4,  8.1, 10.8, 13.5, 16.2, 18.9, 21.6, 24.3, 27. ]),
#  <BarContainer object of 10 artists>)

# %%
years
# Out:
# ['2017',
#  '2012',
#  '2006',
#  '2015',
#  '2016',
#  '2016',
#  '2014',
#  '2017',
#  '2019',
#  '2018',
#  '2019',
#  '2019',
#  '2020',
#  '2017',
#  ' 12+',
#  ' 2019',
#  ' 2019',
#  ' 2016',
#  ' 2019',
#  ' 2012',
#  ' 2013',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2021',
#  ' 2013',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2016',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2015',
#  ' 2015',
#  ' 2018',
#  ' 2016',
#  ' 2019',
#  ' 2020',
#  ' 2016',
#  ' 2017',
#  ' 2017',
#  ' 2020',
#  ' 2018',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2009',
#  ' 2014',
#  ' 2016',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2018',
#  ' 2017',
#  ' 2021',
#  ' 2014',
#  ' 2016',
#  ' 2015',
#  ' 2015',
#  ' 2014',
#  ' 2017',
#  ' 2017',
#  ' 2016',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2016',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2019',
#  ' 2012',
#  ' 2013',
#  ' 2014',
#  ' 2015',
#  ' 2019',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2013',
#  ' 2014',
#  ' 2015',
#  ' 2016',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2015',
#  ' 2016',
#  ' 2018',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2018',
#  ' 2018',
#  ' 2017',
#  ' 2020',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2007',
#  ' 2013',
#  ' 2019',
#  ' 2019',
#  ' 2016',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2018',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2014',
#  ' 2021',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2018',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2015',
#  ' 2018',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2018',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2007',
#  ' 2015',
#  ' 2016',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2021',
#  ' 2021',
#  ' 2019',
#  ' 2018',
#  ' 2019',
#  ' 2013',
#  ' 2014',
#  ' 2020',
#  ' 2017',
#  ' 2013',
#  ' 2011',
#  ' 2013',
#  ' 2007',
#  ' 2012',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2016',
#  ' 2014',
#  ' 2017',
#  ' 2017',
#  ' 2014',
#  ' 2017',
#  ' 2013',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2019',
#  ' 2014',
#  ' 2019',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2013',
#  ' 2013',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2016',
#  ' 2021',
#  ' 2014',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2015',
#  ' 2015',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2015',
#  ' 2018',
#  ' 2018',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2014',
#  ' 2019',
#  nan,
#  ' 2016',
#  ' 2016',
#  ' 2020',
#  ' 2015',
#  ' 2020',
#  ' 2020',
#  ' 2018',
#  ' 2017',
#  ' 2020',
#  ' 2021',
#  ' 2018',
#  ' 2019',
#  ' 2018',
#  ' 2021',
#  ' 2018',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2018',
#  ' 2016',
#  ' 2019',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2017',
#  ' 2020',
#  ' 2011',
#  ' 2015',
#  ' 2018',
#  ' 2017',
#  ' 2017',
#  ' 2014',
#  ' 2016',
#  ' 2015',
#  ' 2019',
#  ' 2019',
#  ' 2021',
#  ' 2020',
#  ' 2015',
#  ' 2012',
#  ' 2013',
#  ' 2016',
#  ' 2016',
#  ' 2021',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2021',
#  ' 2018',
#  ' 2021',
#  ' 2019',
#  ' 2010',
#  ' 2016',
#  ' 2017',
#  ' 2019',
#  ' 2018',
#  ' 2020',
#  ' 2018',
#  ' 2015',
#  ' 2012',
#  ' 2006',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2014',
#  ' 2011',
#  ' 2013',
#  ' 2017',
#  ' 2017',
#  ' 2016',
#  ' 2014',
#  ' 2018',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2007',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2015',
#  ' 2019',
#  ' 2019',
#  ' 2016',
#  ' 2017',
#  ' 2018',
#  ' 2015',
#  ' 2016',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2018',
#  ' 2018',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2013',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2018',
#  ' 2019',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2018',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2016',
#  ' 2019',
#  ' 2020',
#  ' 2006',
#  ' 2021',
#  ' 2013',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2021',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2011',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2017',
#  ' 2014',
#  ' 2011',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2020',
#  ' 2019',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2015',
#  ' 2020',
#  ' 2017',
#  ' 2014',
#  ' 2018',
#  ' 2019',
#  ' 2012',
#  ' 2018',
#  ' 2020',
#  ' 2018',
#  ' 2015',
#  ' 2013',
#  ' 2013',
#  ' 2013',
#  ' 2011',
#  ' 2013',
#  ' 2012',
#  ' 2016',
#  ' 2016',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2016',
#  ' 2016',
#  ' 2014',
#  ' 2012',
#  ' 2013',
#  ' 2013',
#  ' 2017',
#  ' 2017',
#  ' 2016',
#  ' 2016',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2018',
#  ' 2017',
#  ' 2018',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2006',
#  ' 2002',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2008',
#  ' 2015',
#  ' 2017',
#  ' 2017',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2019',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2013',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  nan,
#  ' 2011',
#  ' 2015',
#  ' 2015',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2016',
#  ' 2016',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2008',
#  ' 2011',
#  ' 2012',
#  ' 2019',
#  ' 2021',
#  ' 2020',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2017',
#  ' 2015',
#  ' 2016',
#  ' 2021',
#  ' 2019',
#  ' 2021',
#  ' 2021',
#  ' 2017',
#  ' 2012',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2016',
#  ' 2016',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2016',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2018',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2010',
#  ' 2014',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2016',
#  ' 2014',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2015',
#  ' 2015',
#  ' 2013',
#  ' 2014',
#  ' 2015',
#  ' 2017',
#  ' 2021',
#  ' 2017',
#  ' 2018',
#  ' 2019',
#  ' 2014',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2016',
#  ' 2020',
#  ' 2020',
#  ' 2017',
#  ' 2011',
#  ' 2018',
#  ' 2019',
#  ' 2012',
#  ' 2018',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2021',
#  ' 2021',
#  ' 2021',
#  ' 2013',
#  ' 2019',
#  ' 2018',
#  ' 2014',
#  ' 2006',
#  ' 2017',
#  ' 2016',
#  ' 2020',
#  ' 2017',
#  ' 2018',
#  ' 2021',
#  ' 2014',
#  ' 2010',
#  ' 2019',
#  ' 2019',
#  ' 2021',
#  ' 2013',
#  ' 2013',
#  ' 2013',
#  ' 2013',
#  ' 2012',
#  ' 2015',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2015',
#  ' 2014',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2016',
#  ' 2011',
#  ' 2014',
#  ' 2015',
#  ' 2013',
#  ' 2013',
#  ' 2015',
#  ' 2017',
#  ' 2017',
#  ' 2016',
#  ' 2017',
#  ' 2016',
#  ' 2020',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2016',
#  ' 2016',
#  ' 2017',
#  ' 2017',
#  ' 2015',
#  ' 2018',
#  ' 2007',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2017',
#  ' 2018',
#  ' 2018',
#  ' 2018',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2018',
#  ' 2018',
#  nan,
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2020',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2019',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2020',
#  ' 2019',
#  ' 2020']
